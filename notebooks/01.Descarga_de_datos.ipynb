# %%
import np from numpy
# Out:
# Running cells with 'Python 3.14.4' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Usuario/.local/bin/python3.14.exe -m pip install ipykernel -U --user --force-reinstall'
